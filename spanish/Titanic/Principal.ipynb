# %% [markdown]
# <h1>Análisis de la tripulación del titanic</h1>
#
# El Titanic fue un transatlántico británico, el mayor barco de pasajeros del mundo al finalizar su construcción. Este se hundió el 15 de abril del 1912 durante su viaje inaugural desde Southampton a Nueva York. En este trágico suceso se dice que murieon 1514 personas de 2223 que iban a bordo, lo que lo convierte en uno de los mayores naufragios de la historia.
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/f/fd/RMS_Titanic_3.jpg)
#
# Entre sus pasajeros estaban algunas de las personas más ricas del mundo, además de cientos de inmigrantes irlandeses, británicos y escandinavos que iban en busca de una mejor vida en Norteamérica.
#
# El Titanic recaló en Cherburgo (Francia) y en Queenstown (Irlanda) antes de poner proa al océano Atlántico.
#
# El Titanic chocó contra un iceberg. La colisión abrió varias planchas del casco en su lado de estribor bajo la línea de flotación. Durante dos horas y media el barco se fue hundiendo gradualmente por su parte delantera mientras la popa se elevaba y en este tiempo varios cientos de pasajeros y tripulantes fueron evacuados en los botes salvavidas. Solo se portaban botes salvavidas para 1178 pasajeros, poco más de la mitad de los que iban a bordo en su viaje inaugural y un tercio de su capacidad total.

# %%
# importaciones
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# Vemos que tenemos las variables:
#
# * PassenderId: Identificador para la fila (prescindible)<br>
# * Survived: Saber si sobrevivio esta persona(0 = No; 1 = Sí)<br>
# * Pclass: Clase del pasajero (1 = primera; 2 = segunda; 3 = tercera)<br>
# * Sex: Sexo (male o female)<br>
# * Age: Edad<br>
# * SibSp: Número de hermanos/cónyuges a bordo<br>
# * Parch: Número de padres/niños a bordo<br>
# * Ticked: Número del ticket<br>
# * Fare: Tarifa del pasajero<br>
# * Cabin: Cabina<br>
# * Embarked: Puerto de embarque (C = Cherbourg; Q = Queenstown; S = Southampton)<br>

# %% [markdown]
# Limpiamos la información (eliminando columnas y filas que no utilicemos)

# %%
del data['PassengerId']

# %% [markdown]
# Información ya limpia:

# %%
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# Vamos a analizar los campos primero de todo:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.6+ KB

# %% [markdown]
# Vamos a sacar primero la información general:

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Datos interesantes que vemos:
#
# * Tenemos 891 pasajeros, de los cuales solo 714 se sabe su edad (tenemos 117 pasajeros sin edad).
#
# * Vemos que sobrevivió el 38% de los pasajeros.
#
# * La edad media de la gente era de 29 años.
#
# Tipos de variables:
#
# * Categoricas: Survived, Pclass, Sex, Embarked
# * Numerical: PassengerId, Age, SibSp, Parch, Fare
#
# En la wikipedia pone que había 2223 personas en el Titanic y los botes salvavidas podían llevar 1178 pasajeros. Por lo tanto (1178 * 891) / 2223 = 472 son el número de personas tendrían que poder subir a un bote salvadidas.
#
# Vamos a contar el número de supervivientes para ver si es cierto:

# %%
data['Survived'].sum()
# Out:
# 342

# %% [markdown]
# Vemos que el número de gente que sobrevivió es menor a la capacidad de los botes salvavidas. Esto puede ser debido a que los botes no se llenaron a su máxima capacidad, o mucha gente pereció en los botes (por ejemplo de hipotermia).

# %% [markdown]
# Ahora vamos a buscar correlaciones

# %%
def plot_correlation_map( df ):
    corr = data.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )

# %%
plot_correlation_map(data)

# %% [markdown]
# Vamos a ir característica por característica intentando dar una hipotesis a cada correlación.
#
# Survived:
#
# * Vemos una influencia a la hora de sobrevivir según la clase a la que pertenecieras.
#
# * Vemos la relación entre sobrevivir y la tarifa, lo cuál esta también estrechamente ligado a la clase del pasajero.
#
# Hipótesis: La gente de mayor clase social (es decir, que pagaba por una mejor cabina de tipo A) sobrevivía con mayor frecuencia.
#
# Pclass:
#
# * Vemos la clara influencia entre la clase del pasajero y la tarifa que ha pagado.
#
# * Hay una estrecha relación la clase del pasajero y su edad.
#
# Hipótesis: La mayoría de la gente de la alta sociedad era gente de una avanzada edad.
#
# Age:
#
# * Vemos que hay una relación entre la edad del pasajero y el número de hijos/conyuges.
#
# Hay una gran relación entre Sibsp y Parch.

# %% [markdown]
# Vamos a intentar demostrar la hipótesis de que la gente de mayor clase social (clase A) sobrevivía con mayor frecuencia.

# %%
sns.countplot(data['Pclass'], hue=data['Survived'])

# %% [markdown]
# Vemos como la mayor parte de la gente de clase A sobrevivía. La gente de clase B mitad y mitad y por la último la clase C no solía sobrevivir. Una posible respuesta a esto es porque las cabinas de los pasajeros de clase C se encontraban en la parte inferior del barco, con lo cuál al chocar el iceber en la parte inferior provocó que mucha gente se quedará atrapada bajo el agua. Otra posible respuesta, es que al ser gente de menos recursos no podía optar en muchos casos al bote salvavidas.

# %%
for i in range(3):
    passengerClass = data[data.Pclass == (i+1)].Survived.value_counts()
    # (genteQueSobrevivióDeClaseA / genteTotalDeClaseA) * 100 = % de gente que
    print ("Class of Passenger: ", (i+1), " - percent of survived: ", (passengerClass[1] / passengerClass.sum()) * 100)
# Out:
# Class of Passenger:  1  - percent of survived:  62.962962963
# Class of Passenger:  2  - percent of survived:  47.2826086957
# Class of Passenger:  3  - percent of survived:  24.2362525458
